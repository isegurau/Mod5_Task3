# %%
import pandas as pd
import seaborn as sns

# %%
credit = pd.read_csv(r"C:\Users\i_seg\OneDrive\BIG DATA\DATA ANALISYS\MODULE5\Task2\default of credit card clients.csv", header =1)

# %%
credit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
credit.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
import matplotlib.pyplot as plt #similar to Seaborn library

# %%
header = credit.dtypes.index
print(header)
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
plt.hist(credit['LIMIT_BAL'])
plt.show()

# %%
plt.hist(credit['SEX'])
plt.show()

# %%
plt.hist(credit['EDUCATION'])
plt.show()

# %%
plt.hist(credit['MARRIAGE'])
plt.show()

# %%
plt.hist(credit['AGE'])
plt.show()

# %%
plt.hist(credit['PAY_0'])
plt.show()

# %%
plt.hist(credit['LIMIT_BAL'], bins=4)
# Out:
# (array([2.3283e+04, 6.5110e+03, 2.0000e+02, 6.0000e+00]),
#  array([  10000.,  257500.,  505000.,  752500., 1000000.]),
#  <a list of 4 Patch objects>)

# %%
plt.plot(credit['LIMIT_BAL'])
plt.show()

# %%
x = credit['PAY_0']
y = credit['PAY_2']
plt.scatter(x,y)
plt.show()

# %%
A = credit['BILL_AMT1']
plt.boxplot(A,0,'gD')
plt.show()

# %%
#CORRELATION
corrMat = credit.corr()
print(corrMat)
# Out:
#                                   ID  LIMIT_BAL       SEX  EDUCATION  \
# ID                          1.000000   0.026179  0.018497   0.039177
# LIMIT_BAL                   0.026179   1.000000  0.024755  -0.219161
# SEX                         0.018497   0.024755  1.000000   0.014232
# EDUCATION                   0.039177  -0.219161  0.014232   1.000000
# MARRIAGE                   -0.029079  -0.108139 -0.031389  -0.143464
# AGE                         0.018678   0.144713 -0.090874   0.175061
# PAY_0                      -0.030575  -0.271214 -0.057643   0.105364
# PAY_2                      -0.011215  -0.296382 -0.070771   0.121566
# PAY_3                      -0.018494  -0.286123 -0.066096   0.114025
# PAY_4                      -0.002735  -0.267460 -0.060173   0.108793
# PAY_5                      -0.022199  -0.249411 -0.055064   0.097520
# PAY_6                      -0.020270  -0.235195 -0.044008   0.082316
# BILL_AMT1                   0.019389   0.285430 -0.033642   0.023581
# ...

# %%
covMat = credit.cov()
print(covMat)
# Out:
#                                       ID     LIMIT_BAL          SEX  \
# ID                          7.500250e+07  2.941664e+07    78.356379
# LIMIT_BAL                   2.941664e+07  1.683446e+10  1571.050630
# SEX                         7.835638e+01  1.571051e+03     0.239247
# EDUCATION                   2.681543e+02 -2.247403e+04     0.005502
# MARRIAGE                   -1.314525e+02 -7.323670e+03    -0.008014
# AGE                         1.491057e+03  1.730767e+05    -0.409726
# PAY_0                      -2.975726e+02 -3.954593e+04    -0.031685
# PAY_2                      -1.162770e+02 -4.603765e+04    -0.041442
# PAY_3                      -1.916922e+02 -4.443225e+04    -0.038694
# PAY_4                      -2.769132e+01 -4.057181e+04    -0.034411
# PAY_5                      -2.178600e+02 -3.667056e+04    -0.030521
# PAY_6                      -2.018774e+02 -3.509308e+04    -0.024754
# BILL_AMT1                   1.236447e+07  2.727020e+09 -1211.694332
# ...

# %%
# Information about the data set
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                            30000 non-null int64
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null category
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null int64
# BILL_AMT2                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# BILL_AMT4                     30000 non-null int64
# ...

# %%
# Number of clients in each gender
credit.groupby('SEX')['SEX'].count()
# Out:
# Series([], Name: SEX, dtype: int64)

# %%
import seaborn as sns 
# Instead of a group by, use seaborn to plot the count of clients in each class
fg = sns.factorplot('SEX', data=credit, kind='count', aspect=1.5)
fg.set_xlabels('Class')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-9093b047bced> in <module>
#       1 import seaborn as sns
#       2 # Instead of a group by, use seaborn to plot the count of clients in each class
# ----> 3 fg = sns.factorplot('SEX', data=credit, kind='count', aspect=1.5)
#       4 fg.set_xlabels('Class')
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in factorplot(*args, **kwargs)
#    3674     kwargs.setdefault("kind", "point")
#    3675
# -> 3676     return catplot(*args, **kwargs)
#    3677
#    3678
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
# ...

# %%
# Number of men and women in each of the education level
credit.groupby(['SEX', 'EDUCATION'])['SEX'].count()
# Out:
# SEX  EDUCATION
# 1    0               8
#      1            4354
#      2            5374
#      3            1990
#      4              42
#      5              95
#      6              25
# 2    0               6
#      1            6231
#      2            8656
#      3            2927
#      4              81
#      5             185
#      6              26
# Name: SEX, dtype: int64

# %%
#Parse sex to category
credit['SEX'] = credit.SEX.astype('category')

# %%
#Parse EDUCATION to category
credit['EDUCATION'] = credit.EDUCATION.astype('category')

# %%
#Parse EDUCATION to category
credit['MARRIAGE'] = credit.MARRIAGE.astype('category')

# %%
del a[0]

# %%
#Check missing values
credit.isnull()
#there is not missing data
#This in case we found missing values
# will replace  Nan value in dataframe with value -99999  
#df.replace(to_replace = np.nan, value =-99999)
# Out:
#           ID  LIMIT_BAL    SEX  EDUCATION  MARRIAGE    AGE  PAY_0  PAY_2  \
# 0      False      False  False      False     False  False  False  False
# 1      False      False  False      False     False  False  False  False
# 2      False      False  False      False     False  False  False  False
# 3      False      False  False      False     False  False  False  False
# 4      False      False  False      False     False  False  False  False
# ...      ...        ...    ...        ...       ...    ...    ...    ...
# 29995  False      False  False      False     False  False  False  False
# 29996  False      False  False      False     False  False  False  False
# 29997  False      False  False      False     False  False  False  False
# 29998  False      False  False      False     False  False  False  False
# 29999  False      False  False      False     False  False  False  False
#
#        PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# ...

# %%
# Out:
#           ID  LIMIT_BAL     SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  \
# 0          1      20000  Female          2         1   24      2      2
# 1          2     120000  Female          2         2   26     -1      2
# 2          3      90000  Female          2         2   34      0      0
# 3          4      50000  Female          2         1   37      0      0
# 4          5      50000    Male          2         1   57     -1      0
# ...      ...        ...     ...        ...       ...  ...    ...    ...
# 29995  29996     220000    Male          3         1   39      0      0
# 29996  29997     150000    Male          3         2   43     -1     -1
# 29997  29998      30000    Male          2         2   37      4      3
# 29998  29999      80000    Male          3         1   41      1     -1
# 29999  30000      50000    Male          2         1   46      0      0
#
#        PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# ...

# %%
credit.apply(pd.Series.replace, to_replace=1, value="Male")
# Out:
#           ID  LIMIT_BAL   SEX EDUCATION MARRIAGE  AGE PAY_0 PAY_2 PAY_3 PAY_4  \
# 0       Male      20000     2         2     Male   24     2     2    -1    -1
# 1          2     120000     2         2        2   26    -1     2     0     0
# 2          3      90000     2         2        2   34     0     0     0     0
# 3          4      50000     2         2     Male   37     0     0     0     0
# 4          5      50000  Male         2     Male   57    -1     0    -1     0
# ...      ...        ...   ...       ...      ...  ...   ...   ...   ...   ...
# 29995  29996     220000  Male         3     Male   39     0     0     0     0
# 29996  29997     150000  Male         3        2   43    -1    -1    -1    -1
# 29997  29998      30000  Male         2        2   37     4     3     2    -1
# 29998  29999      80000  Male         3     Male   41  Male    -1     0     0
# 29999  30000      50000  Male         2     Male   46     0     0     0     0
#
# ...

# %%
credit.apply(pd.Series.replace, to_replace=2, value="Female")
# Out:
#            ID  LIMIT_BAL     SEX EDUCATION MARRIAGE  AGE   PAY_0   PAY_2  \
# 0           1      20000  Female    Female        1   24  Female  Female
# 1      Female     120000  Female    Female   Female   26      -1  Female
# 2           3      90000  Female    Female   Female   34       0       0
# 3           4      50000  Female    Female        1   37       0       0
# 4           5      50000       1    Female        1   57      -1       0
# ...       ...        ...     ...       ...      ...  ...     ...     ...
# 29995   29996     220000       1         3        1   39       0       0
# 29996   29997     150000       1         3   Female   43      -1      -1
# 29997   29998      30000       1    Female   Female   37       4       3
# 29998   29999      80000       1         3        1   41       1      -1
# 29999   30000      50000       1    Female        1   46       0       0
#
#         PAY_3 PAY_4  ... BILL_AMT4 BILL_AMT5  BILL_AMT6  PAY_AMT1 PAY_AMT2  \
# ...
